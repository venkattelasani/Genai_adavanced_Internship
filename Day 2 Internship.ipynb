# %%
#Write a python program to implement replace method using loop. If sub_str is found in my_str then it will replace the first 
#occurrence of sub_str with new_str else it will will print sub_str not found:-

#Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck', new_str = 'Pack'
#Output:- 'Peter Piper Picked A Pack Of Pickled Peppers.'

# %%
# Challenges:-
- Find the substring in the given or the main string

# %%
my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'

# %%
my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'
new_str = 'Pack'

output = '' # to store the final output 

for i in range(len(my_str)):
    print(my_str[i:i+len(sub_str)]) # moving window concept

# %%
len(my_str)
range(45) # range(0-44)
i = 0
my_str[0:4]
i = 1
my_str[1:5]
# Out:
# 45

# %%
# iterate over the character or elements of the iterable object 
for i(var) in iterable_object:#(string, range, list, tuples. dictonary, set or frozenset)
    print(i)

# %%
a = 'Python'

for i in a:
    print(i)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# iterate over the index 
for i(var) in range(len(iterable_object)):
    print(i)

# %%
a = 'python'

for i in range(len(a)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# iterate over both the elements and the index as well 

for i(var) in range(len(iterable_object)):
    print(i, var_storing_iterable_object[i])

# %%
a = 'python'

for i in range(len(a)):
    print(i, a[i])
# Out:
# 0 p
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n

# %%
my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'
new_str = 'Pack'

output = '' # to store the final output 

for i in range(len(my_str)):
    print(my_str[i:i+len(sub_str)]) # moving window concept
# Out:
# Pete
# eter
# ter
# er P
# r Pi
#  Pip
# Pipe
# iper
# per
# er P
# r Pi
#  Pic
# Pick
# icke
# cked
# ked
# ed A
# d A
#  A P
# A Pe
#  Pec
# Peck
# eck
# ck O
# k Of
#  Of
# Of P
# f Pi
#  Pic
# Pick
# ickl
# ckle
# kled
# led
# ed P
# d Pe
#  Pep
# Pepp
# eppe
# pper
# pers
# ers.
# rs.
# s.
# .

# %%
my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'
new_str = 'Pack'

output = '' # to store the final output 

for i in range(len(my_str)):
    if my_str[i:i+len(sub_str)] != sub_str:
        # add the character at that index to the output string
        output += my_str[i]
    else:
        output += new_str
        i = i+len(sub_str)

print(output)
# Out:
# Peter Piper Picked A Packeck Of Pickled Peppers.

# %%
my_str = 'She sells sea shells on the sea shore'
sub_str = 'sea'
new_str = 'see'

output = '' # to store the final output 
i = 0
while i<len(my_str):
    if my_str[i:i+len(sub_str)] != sub_str:
        # add the character at that index to the output string
        output += my_str[i]
        i += 1
    else:
        output += new_str
        i = i+len(sub_str)

print(output)
# Out:
# She sells see shells on the see shore

# %%
my_str = 'She sells sea shells on the sea shore'
sub_str = 'sea'
new_str = 'see'

output = '' # to store the final output 

for i in range(len(my_str)):
    if my_str[i:i+len(sub_str)] != sub_str:
        # add the character at that index to the output string
        output += my_str[i]
    else:
        output = output[0:i]+new_str+my_str[i+len(sub_str):]
        break

print(output)
# Out:
# She sells see shells on the sea shore

# %%
def mimic_replace(my_str, sub_str, new_str):   
    output = '' # to store the final output 
    i = 0
    while i<len(my_str):
        if my_str[i:i+len(sub_str)] != sub_str:
            # add the character at that index to the output string
            output += my_str[i]
            i += 1
        else:
            output += new_str
            i = i+len(sub_str)
    return output

# %%
my_str = 'She sells sea shells on the sea shore'
sub_str = 'sea'
new_str = 'see'

# %%
mimic_replace(my_str, sub_str, new_str)
# Out:
# 'She sells see shells on the see shore'

# %%
mimic_replace(my_str,'s','S')
# Out:
# 'She SellS Sea ShellS on the Sea Shore'

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
#Write a python program to find below output (implements rjust and ljust) using loop:-

#Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck', 
#Output:- '*********************Peck********************'

# %%
my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'

output = '' # to store the final output 
i = 0
while i<len(my_str):
    if my_str[i:i+len(sub_str)] != sub_str:
        # add the *
        output += '*'
        i += 1
    else:
        output += sub_str
        i = i+len(sub_str)

print(output)
# Out:
# *********************Peck********************

# %%
#Write a Python program to sort a list in ascending order using loop.
#Input:- [100,10,1,298,65,483,49876,2,80,9,9213]
#Output:- [1,2,9,10,65,80,100,298,483,9213,49876]

# using bubble sort 
lst = [100,10,1,298,65,483,49876,2,80,9,9213]

for i in range(len(lst)):
    for j in range(len(lst)-i-1):
        if lst[j]>lst[j+1]:
            lst[j], lst[j+1] = lst[j+1], lst[j]
    print(lst)
    print()

print(lst)
# Out:
# [10, 1, 100, 65, 298, 483, 2, 80, 9, 9213, 49876]
#
# [1, 10, 65, 100, 298, 2, 80, 9, 483, 9213, 49876]
#
# [1, 10, 65, 100, 2, 80, 9, 298, 483, 9213, 49876]
#
# [1, 10, 65, 2, 80, 9, 100, 298, 483, 9213, 49876]
#
# [1, 10, 2, 65, 9, 80, 100, 298, 483, 9213, 49876]
#
# [1, 2, 10, 9, 65, 80, 100, 298, 483, 9213, 49876]
#
# [1, 2, 9, 10, 65, 80, 100, 298, 483, 9213, 49876]
#
# [1, 2, 9, 10, 65, 80, 100, 298, 483, 9213, 49876]
#
# [1, 2, 9, 10, 65, 80, 100, 298, 483, 9213, 49876]
#
# [1, 2, 9, 10, 65, 80, 100, 298, 483, 9213, 49876]
#
# [1, 2, 9, 10, 65, 80, 100, 298, 483, 9213, 49876]
#
# [1, 2, 9, 10, 65, 80, 100, 298, 483, 9213, 49876]
