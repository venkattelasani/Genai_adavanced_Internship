# %% [markdown]
# # ✅ 1. Class (Blueprint)
#
# A **class** is like a **blueprint**, **design**, or **template** from which objects are created.
#
# It defines:
#
# * **Attributes (variables)** → store data
# * **Methods (functions)** → store behaviour
#
# Think of a **class like a form**, and an object is a **filled form**.
#
# ---
#
# ### ✔ Example
#
# ```python
# class Student:
#     college = "ABC College"   # class variable (shared by all students)
#
#     def __init__(self, name, marks):
#         self.name = name        # object variable
#         self.marks = marks      # object variable
#
#     def show(self):
#         print(self.name, self.marks)
# ```
#
# ### 🔍 Explanation
#
# | Component                 | Meaning                                                 |
# | ------------------------- | ------------------------------------------------------- |
# | `class Student:`          | Class definition                                        |
# | `college`                 | Class variable (same for all objects)                   |
# | `__init__`                | Constructor (runs automatically when object is created) |
# | `self.name`, `self.marks` | Object variables (different for each object)            |
# | `show()`                  | Method that prints object’s data                        |
#
# ---
#
# # ✅ 2. Object (Instance of a Class)
#
# An **object** is a **real-world entity** created from a class.
#
# A class is the plan…
# An object is the actual building.
#
# Each object has **its own data**.
#
# ---
#
# ### ✔ Example
#
# ```python
# s1 = Student("Mayank", 90)
# s1.show()
# ```
#
# ### 🔍 Explanation
#
# * `s1` is an **object** of class `Student`
# * `"Mayank"` → stored in `self.name`
# * `90` → stored in `self.marks`
# * `s1.show()` → prints values of that object
#
# ---

# %% [markdown]
# # ✅ Types of Variables in Python OOPS
#
# Python has **3 types of variables**:
#
# 1️⃣ **Instance Variables**
# 2️⃣ **Class Variables**
# 3️⃣ **Local Variables**
#
# Let’s break each one down with simple logic + code.
#
# ---
#
# # 🔵 1. Instance Variables (Object-Level Variables)
#
# ✔ These belong to **individual objects**.
# ✔ Created inside the **constructor (`__init__`)** or inside **object methods** using `self`.
# ✔ **Every object gets its own copy**.
#
# ### Example:
#
# ```python
# class Student:
#     def __init__(self, name, marks):
#         self.name = name         # instance variable
#         self.marks = marks       # instance variable
#
# s1 = Student("Mayank", 90)
# s2 = Student("Rohan", 85)
#
# print(s1.name, s1.marks)   # Mayank 90
# print(s2.name, s2.marks)   # Rohan 85
# ```
#
# 👉 `s1` and `s2` have **different name and marks** → stored separately.
#
# ---
#
# # 🔵 2. Class Variables (Static Variables)
#
# ✔ Belong to the **class**, not to any object.
# ✔ Created **outside** all methods but **inside the class**.
# ✔ **Shared among all objects**.
# ✔ All objects see the **same value** unless overridden.
#
# ### Example:
#
# ```python
# class Student:
#     college = "ABC College"      # class variable
#
#     def __init__(self, name):
#         self.name = name         # instance variable
#
# s1 = Student("Mayank")
# s2 = Student("Rohan")
#
# print(s1.college)   # ABC College
# print(s2.college)   # ABC College
# ```
#
# 👉 `college` is same for all students → **only one copy** in memory.
#
# ---
#
# # 🔵 3. Local Variables (Method-Level Variables)
#
# ✔ Variables created **inside a method**.
# ✔ Exist **only inside that method**.
# ✔ Destroyed once the method finishes.
#
# ### Example:
#
# ```python
# class Student:
#     def show(self):
#         msg = "Hello Students"   # local variable
#         print(msg)
# ```
#
# 👉 `msg` exists only while `show()` method is running.
#
# You **cannot access** `msg` outside the method.
#
# ---
#
# # 🟩 Summary Table
#
# | Variable Type         | Where Declared?                                  | Scope                   | Lifetime                 |
# | --------------------- | ------------------------------------------------ | ----------------------- | ------------------------ |
# | **Instance Variable** | Inside constructor or object method using `self` | Per object              | As long as object exists |
# | **Class Variable**    | Inside class, outside methods                    | Shared by all objects   | Till program ends        |
# | **Local Variable**    | Inside any method                                | Only inside that method | Method execution only    |
#
# ---

# %% [markdown]
# # ⭐ Types of Methods in Python
#
# Python has **3 types of methods** inside a class:
#
# 1️⃣ **Instance Methods**
# 2️⃣ **Class Methods**
# 3️⃣ **Static Methods**
#
# Let’s understand these one by one.
#
# ---
#
# # 🔵 1. Instance Method
#
# ✔ The most common method type
# ✔ Works on **object-level data (instance variables)**
# ✔ Must have `self` as the **first parameter**
#
# ### Example:
#
# ```python
# class Student:
#     def __init__(self, name, marks):
#         self.name = name
#         self.marks = marks
#
#     def show(self):     # instance method
#         print(self.name, self.marks)
#
# s1 = Student("Mayank", 90)
# s1.show()              # uses instance variables
# ```
#
# 👉 `self` represents **current object**.
#
# 👉 Used when you want to **access or modify object data**.
#
# ---
#
# # 🔵 2. Class Method
#
# ✔ Works on **class-level data (class variables)**
# ✔ Has access to the **class**, not objects
# ✔ Must have `cls` as the **first parameter**
# ✔ Declared using `@classmethod`
#
# ### Example:
#
# ```python
# class Student:
#     college = "ABC College"
#
#     @classmethod
#     def change_college(cls, new_name):
#         cls.college = new_name    # modifies class variable
# ```
#
# Usage:
#
# ```python
# Student.change_college("XYZ University")
# print(Student.college)
# ```
#
# 👉 All objects will now see `"XYZ University"`.
#
# 👉 Used when you want to **modify or access class variables**.
#
# ---
#
# # 🔵 3. Static Method
#
# ✔ No automatic `self` or `cls`
# ✔ Does NOT access object data
# ✔ Does NOT access class data
# ✔ Behaves like a **normal function inside a class**
# ✔ Declared using `@staticmethod`
#
# ### Example:
#
# ```python
# class MathOps:
#     @staticmethod
#     def add(a, b):
#         return a + b
# ```
#
# Usage:
#
# ```python
# print(MathOps.add(10, 20))
# ```
#
# 👉 No object or class data is used.
#
# 👉 Used when the logic is **independent** of class/object.
#
# ---
#
# # 🟩 Perfect Summary Table
#
# | Method Type         | First Parameter | Access Instance Data? | Access Class Data? | Decorator     |
# | ------------------- | --------------- | --------------------- | ------------------ | ------------- |
# | **Instance Method** | self            | ✔ Yes                 | ✔ Yes              | No decorator  |
# | **Class Method**    | cls             | ✖ No                  | ✔ Yes              | @classmethod  |
# | **Static Method**   | none            | ✖ No                  | ✖ No               | @staticmethod |
#
# ---

# %% [markdown]
# # ⭐ INHERITANCE IN PYTHON (Simple Explanation)
#
# **Inheritance** is the process where **one class (child)** acquires the **properties and methods** of **another class (parent)**.
#
# 👉 It helps in **code reusability**
# 👉 Makes programs **organized and structured**
#
# ---
#
# # 🔵 1. Basic Inheritance
#
# ### Example:
#
# ```python
# class Parent:
#     def show(self):
#         print("This is Parent class")
#
# class Child(Parent):
#     pass
#
# c = Child()
# c.show()
# ```
#
# ✔ `Child` inherited the `show()` method
# ✔ No need to rewrite the same code again → **reusability**
#
# ---
#
# # ⭐ Types of Inheritance
#
# Python supports **5 types** of inheritance:
#
# 1️⃣ Single Inheritance
# 2️⃣ Multilevel Inheritance
# 3️⃣ Multiple Inheritance
# 4️⃣ Hierarchical Inheritance
# 5️⃣ Hybrid Inheritance
#
# Let’s understand each with simple diagrams + examples.
#
# ---
#
# # 🔵 1. Single Inheritance
#
# ➡ One parent → One child
#
# ```
# Parent
#    |
# Child
# ```
#
# ```python
# class Parent:
#     pass
#
# class Child(Parent):
#     pass
# ```
#
# ---
#
# # 🔵 2. Multilevel Inheritance
#
# ➡ Parent → Child → Grandchild
#
# ```
# GrandParent
#      |
#   Parent
#      |
#   Child
# ```
#
# ```python
# class A:
#     pass
#
# class B(A):
#     pass
#
# class C(B):
#     pass
# ```
#
# ---
#
# # 🔵 3. Multiple Inheritance
#
# ➡ One child inherits from **multiple parents**
#
# ```
# Parent1   Parent2
#      \     /
#       \   /
#        Child
# ```
#
# ```python
# class A:
#     pass
#
# class B:
#     pass
#
# class C(A, B):
#     pass
# ```
#
# ---
#
# # 🔵 4. Hierarchical Inheritance
#
# ➡ One parent → Multiple children
#
# ```
#      Parent
#      /    \
#  Child1   Child2
# ```
#
# ```python
# class Parent:
#     pass
#
# class Child1(Parent):
#     pass
#
# class Child2(Parent):
#     pass
# ```
#
# ---
#
# # 🔵 5. Hybrid Inheritance
#
# ➡ Combination of multiple types.
#
# Example: Single + Multiple
#
# ---
#
# # ⭐ MRO (Method Resolution Order)
#
# MRO decides **which class method is executed first** when multiple inheritance is used.
#
# Python uses **C3 Linearization Algorithm**.
#
# You can check MRO using:
#
# ```python
# print(ClassName.mro())
# ```
#
# ### Example:
#
# ```python
# class A: pass
# class B: pass
# class C(A, B): pass
#
# print(C.mro())
# ```
#
# Output will show order like:
#
# ```
# [C, A, B, object]
# ```
#
# ---
#
# # ⭐ super() Method (Very Important)
#
# `super()` is used to call the **parent class constructor or method** inside the child class.
#
# ### Example:
#
# ```python
# class Parent:
#     def __init__(self):
#         print("Parent constructor")
#
# class Child(Parent):
#     def __init__(self):
#         super().__init__()
#         print("Child constructor")
#
# c = Child()
# ```
#
# Output:
#
# ```
# Parent constructor
# Child constructor
# ```
#
# 👉 `super()` ensures parent initialization happens first.
#
# ---
#
# # 🟩 Summary (Very Clean)
#
# | Topic       | Meaning                                            |
# | ----------- | -------------------------------------------------- |
# | Inheritance | Child gets parent’s data + methods                 |
# | Purpose     | Reusability + organization                         |
# | Types       | Single, Multilevel, Multiple, Hierarchical, Hybrid |
# | MRO         | Decides method search order                        |
# | super()     | Calls parent constructor/method                    |
#
# ---

# %% [markdown]
# # ⭐ Encapsulation in Python
#
# **Encapsulation** means **binding data (variables) and methods (functions)** together into a single unit (class) and **controlling access** to them.
#
# 👉 You hide the internal details
# 👉 You expose only what is necessary
# 👉 Protects data from accidental modification
#
# Just like how a **mobile phone hides internal circuits** and exposes only buttons to users.
#
# ---
#
# # ⭐ 1. Public Members
#
# These are **accessible from anywhere**.
# In Python, **all variables and methods are public by default**.
#
# ### Example:
#
# ```python
# class Student:
#     def __init__(self, name):
#         self.name = name     # public variable
#
# s = Student("Mayank")
# print(s.name)               # Accessible everywhere
# ```
#
# ---
#
# # ⭐ 2. Protected Members (`_variable`)
#
# ✔ Indicated by **single underscore (_) prefix**
# ✔ Should be accessed **inside the class or its subclasses**
# ✔ Not strictly restricted (Python follows "we trust the developer")
#
# ### Example:
#
# ```python
# class Student:
#     def __init__(self):
#         self._marks = 90    # protected variable
#
# class Child(Student):
#     def display(self):
#         print(self._marks)  # accessible in derived class
# ```
#
# ---
#
# # ⭐ 3. Private Members (`__variable`)
#
# ✔ Indicated by **double underscore (__) prefix**
# ✔ Can be accessed **only inside the class**
# ✔ Python performs **Name Mangling** → internal rename to `_ClassName__variable`
#
# ### Example:
#
# ```python
# class Student:
#     def __init__(self):
#         self.__salary = 50000   # private variable
#
#     def show(self):
#         print(self.__salary)    # allowed
#
# s = Student()
# s.show()
# ```
#
# Trying this:
#
# ```python
# print(s.__salary)
# ```
#
# ❌ Error → because it's private.
#
# But internally you CAN access with name-mangling:
#
# ```python
# print(s._Student__salary)
# ```
#
# ---
#
# # ⭐ Why Encapsulation?
#
# ✔ Protects data from accidental modification
# ✔ Clear separation of "what is exposed" vs "what is hidden"
# ✔ Maintains security and abstraction
# ✔ Prevents direct access to sensitive info
# ✔ Required in large applications to avoid bugs
#
# ---
#
# # ⭐ Encapsulation with Getter & Setter
#
# Used when you want **controlled access** to a private variable.
#
# ### Example:
#
# ```python
# class Bank:
#     def __init__(self):
#         self.__balance = 1000
#
#     def get_balance(self):          # getter
#         return self.__balance
#
#     def set_balance(self, amount):  # setter
#         if amount > 0:
#             self.__balance = amount
#         else:
#             print("Invalid amount")
# ```
#
# Usage:
#
# ```python
# b = Bank()
# print(b.get_balance())
# b.set_balance(5000)
# ```
#
# ---
#
# # 🟩 Summary Table
#
# | Type          | Syntax  | Access            | Use                      |
# | ------------- | ------- | ----------------- | ------------------------ |
# | **Public**    | `var`   | Anywhere          | Default behavior         |
# | **Protected** | `_var`  | Class + Subclass  | Indicates “internal use” |
# | **Private**   | `__var` | Only inside class | Sensitive data           |
#
# ---

# %% [markdown]
# # ⭐ What is Polymorphism?
#
# **Polymorphism = Many forms**
#
# A single function, method, or operator behaves **differently** depending on the context.
#
# ---
#
# # ⭐ 1. Method Overriding (Runtime Polymorphism)
#
# ✔ Happens in **inheritance**
# ✔ Child class provides **its own implementation** of a method already present in parent class.
#
# ### Example:
#
# ```python
# class Animal:
#     def sound(self):
#         print("Animal makes sound")
#
# class Dog(Animal):
#     def sound(self):       # overriding
#         print("Dog barks")
#
# a = Animal()
# d = Dog()
#
# a.sound()   # Animal makes sound
# d.sound()   # Dog barks
# ```
#
# 👉 Same method name → Different behavior based on object.
#
# ---
#
# # ⭐ 2. Method Overloading (Compile-Time Polymorphism)
#
# ✔ In many languages (Java/C++), overloading means **same method name, different parameters**
# ✔ Python **does NOT support traditional method overloading**
# ✔ Python handles missing arguments using *default parameters* or `*args`.
#
# ### Example (Python way — not true overloading):
#
# ```python
# class MathOps:
#     def add(self, a=0, b=0, c=0):
#         return a + b + c
#
# m = MathOps()
# print(m.add(10, 20))      # 30
# print(m.add(10, 20, 30))  # 60
# ```
#
# 👉 Python achieves similar behavior using default arguments.
#
# ---
#
# # ⭐ 3. Operator Overloading
#
# ✔ Python allows you to **change the behavior of built-in operators**
# ✔ Achieved using **dunder methods** like `__add__`, `__sub__`, `__mul__`, etc.
#
# ### Example:
#
# ```python
# class Book:
#     def __init__(self, pages):
#         self.pages = pages
#
#     def __add__(self, other):      # operator overloading
#         return self.pages + other.pages
#
# b1 = Book(100)
# b2 = Book(200)
#
# print(b1 + b2)   # 300
# ```
#
# 👉 `+` now adds pages of two books.
#
# ---
#
# # ⭐ 4. Duck Typing
#
# ✔ "If it **looks** like a duck and **quacks** like a duck, it **is** a duck."
#
# Python checks **behavior**, not the type of object.
#
# ### Example:
#
# ```python
# class Dog:
#     def sound(self):
#         print("Bark")
#
# class Cat:
#     def sound(self):
#         print("Meow")
#
# def make_sound(animal):
#     animal.sound()       # Doesn't care which class it belongs to
#
# make_sound(Dog())
# make_sound(Cat())
# ```
#
# 👉 Python only looks at whether `.sound()` exists.
# No need for strict type checking.
#
# ---
#
# # ⭐ Summary Table
#
# | Concept                  | Meaning                                   | Python Support                 |
# | ------------------------ | ----------------------------------------- | ------------------------------ |
# | **Method Overriding**    | Child class rewrites parent method        | ✔ Fully supported              |
# | **Method Overloading**   | Same method, different arguments          | ❌ Not supported (use defaults) |
# | **Operator Overloading** | Redefining operators using dunder methods | ✔ Supported                    |
# | **Duck Typing**          | Behavior matters, not type                | ✔ Strongly supported           |
#
# ---

# %% [markdown]
# # ⭐ What is Abstraction?
#
# **Abstraction means hiding internal details and showing only the essential features.**
#
# Example in real life:
#
# * You use a **mobile phone** without knowing the internal circuits.
# * You drive a **car** without understanding the engine.
#
# In OOPS:
#
# 👉 You **show only what is necessary**
# 👉 You **hide complexity**
#
# ---
#
# # ⭐ How Abstraction is Implemented in Python?
#
# Python uses:
#
# ### ✔ **Abstract Classes**
#
# ### ✔ **Abstract Methods**
#
# Provided by the module:
#
# ```python
# from abc import ABC, abstractmethod
# ```
#
# ---
#
# # ⭐ 1. Abstract Class
#
# ✔ A class that contains **one or more abstract methods**
# ✔ **Cannot be instantiated** (you cannot create objects of this class)
# ✔ Serves as a **template** for all child classes
#
# ### Example:
#
# ```python
# from abc import ABC, abstractmethod
#
# class Animal(ABC):
#     @abstractmethod
#     def sound(self):
#         pass
# ```
#
# 👉 `Animal` is an abstract class.
# 👉 It has one abstract method `sound()`.
#
# ---
#
# # ⭐ 2. Abstract Method
#
# ✔ A method declared but **not implemented**
# ✔ Child class **must** implement it
# ✔ If child skips implementation → **Error**
#
# ### Example:
#
# ```python
# class Dog(Animal):
#     def sound(self):
#         print("Bark")
# ```
#
# Now usage:
#
# ```python
# d = Dog()
# d.sound()
# ```
#
# ---
#
# # ⭐ Why abstract classes cannot create objects?
#
# Because incomplete methods exist inside them.
# Python forces you to implement the missing methods in child classes.
#
# Example:
#
# ```python
# a = Animal()
# ```
#
# ❌ Error: You can't instantiate abstract class with abstract methods.
#
# ---
#
# # ⭐ 3. Partial Implementation (Very Important)
#
# Abstract classes can have:
#
# * Some **abstract methods** (must be overridden)
# * Some **normal methods** (already implemented)
#
# ### Example:
#
# ```python
# class Animal(ABC):
#     @abstractmethod
#     def sound(self):
#         pass
#
#     def info(self):
#         print("This is an animal")
# ```
#
# 👉 Child must implement `sound()`
# 👉 Child can directly use `info()` without overriding
#
# ---
#
# # ⭐ 4. Why Use Abstraction? (Interview Points)
#
# ✔ Hides unnecessary details
# ✔ Reduces complexity
# ✔ Improves security (hides sensitive logic)
# ✔ Forces child classes to follow rules
# ✔ Makes large systems structured
#
# Example:
#
# * Payment gateway
# * ATM System
# * Machine Learning model interface
# * Vehicle base class (all vehicles must implement start/stop)
#
# ---
#
# # ⭐ Mini Example — ATM Model
#
# ```python
# from abc import ABC, abstractmethod
#
# class ATM(ABC):
#     @abstractmethod
#     def withdraw(self):
#         pass
#
#     @abstractmethod
#     def check_balance(self):
#         pass
#
# class HDFC_ATM(ATM):
#     def withdraw(self):
#         print("Withdraw from HDFC ATM")
#
#     def check_balance(self):
#         print("Check balance from HDFC ATM")
#
# h = HDFC_ATM()
# h.withdraw()
# ```
#
# ---
#
# # 🟩 Summary Table
#
# | Feature                     | Abstract Class             | Abstract Method      |
# | --------------------------- | -------------------------- | -------------------- |
# | Can contain normal methods? | ✔ Yes                      | ❌ No                 |
# | Must child implement?       | ❌ Not required             | ✔ Required           |
# | Can create object?          | ❌ No                       | ❌ No                 |
# | Purpose                     | Template for child classes | Force implementation |
#
# ---
